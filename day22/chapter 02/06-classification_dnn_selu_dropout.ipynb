# %% [markdown]
# # fashion_minst分类实战

# %%
import torch
from torchvision import datasets, transforms

# 定义数据预处理
transform = transforms.Compose([
    transforms.ToTensor(),#将PIL.Image变换成torch.Tensor，并且将像素值归一化到[0,1]
    transforms.Normalize((0.285,), (0.352,)),  # 标准化：均值0.5，标准差0.5，将像素分布到[-1,1]
])

# 下载并加载训练数据集
full_train_dataset = datasets.FashionMNIST(root='./data', train=True, download=False, transform=transform)

# 从训练集中分出5000样本作为验证集
train_size = len(full_train_dataset) - 5000
val_size = 5000

#random_split打乱样本
generator = torch.Generator().manual_seed(42)
train_dataset, val_dataset = torch.utils.data.random_split(full_train_dataset, [train_size, val_size],generator=generator)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)  # batch_size是一个批次样本的数量
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=64, shuffle=False)

# 下载并加载测试数据集
test_dataset = datasets.FashionMNIST(root='./data', train=False, download=False, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# 计算train_dataset的所有图像的均值和标准差
import numpy as np

# 将train_dataset的所有图片展开并拼接，获得像素值
all_imgs = []
for i in range(len(train_dataset)):
    img = train_dataset[i][0].numpy()  # (1,28,28)
    all_imgs.append(img)
all_imgs = np.concatenate(all_imgs, axis=0)  # (N,28,28) 拼成 (N,28,28)（或更精确地是(55000,1,28,28)拼成(55000,28,28)）

# 因为ToTensor后是float,且train_dataset来自random_split（依然只有一通道），可直接求整体均值
mean = all_imgs.mean()
std = all_imgs.std()
print("Train mean:", mean)
print("Train std:", std)
# Out:
# Train mean: 0.0016071055
# Train std: 1.0020698

# %%
import matplotlib.pyplot as plt

# FashionMNIST类别名称
class_names = full_train_dataset.classes

# 可视化train_dataset前15个样本，并显示类别名称
fig, axs = plt.subplots(3, 5, figsize=(10, 6))
axs = axs.flatten()

for i in range(15):
    # 这里train_dataset[i]会返回(img, label)两个值，
    # img是第i个样本的图像（已做Tensor变换），label是对应的类别标签。
    # 因为train_dataset由torch.utils.data.random_split分割自原始的Dataset，继承了其__getitem__方法，原始FashionMNIST的__getitem__返回图像和标签两个值。
    img, label = train_dataset[i]
    img = img.squeeze().numpy()  # 变成2D numpy数组  将(1,28,28)压缩成(28,28)
    axs[i].imshow(img, cmap='gray')
    axs[i].set_title(class_names[label])
    axs[i].axis('off')

plt.tight_layout()
plt.show()

# %%
import torch.nn as nn

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, 300)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(300, 100)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(100, 10)
        
    def forward(self, x):
        x = x.view(x.size(0), -1)  # 展平成(batch_size, 784)
        x = self.fc1(x))
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        return x

# %%
import torch

img, label = train_dataset[0]
img = img.unsqueeze(0)  # 增加batch维度，形状变为(1, 1, 28, 28) 或 (1, 28, 28)
model = NeuralNetwork()
output = model(img)
print("Logits:", output)
print("Predicted class:", torch.argmax(output, dim=1).item(), "True class:", label)
# Out:
# Before view: torch.Size([1, 1, 28, 28])
# After view: torch.Size([1, 784])
# After fc1: torch.Size([1, 300])
# After relu1: torch.Size([1, 300])
# After fc2: torch.Size([1, 100])
# After relu2: torch.Size([1, 100])
# After fc3: torch.Size([1, 10])
# Logits: tensor([[ 0.0397,  0.0749,  0.1257, -0.0802, -0.1226,  0.0551, -0.1094,  0.1313,
#          -0.0932, -0.0584]], grad_fn=<AddmmBackward0>)
# Predicted class: 7 True class: 9

# %%
for images, labels in train_loader:
    print("images shape:", images.shape) #(bs,ch,h,w)
    print("labels shape:", labels.shape) #(bs)
    break  # 只输出第一个batch
# Out:
# images shape: torch.Size([64, 1, 28, 28])
# labels shape: torch.Size([64])

# %%
output = model(images)
print("Logits:", output.shape)
# Out:
# Before view: torch.Size([64, 1, 28, 28])
# After view: torch.Size([64, 784])
# After fc1: torch.Size([64, 300])
# After relu1: torch.Size([64, 300])
# After fc2: torch.Size([64, 100])
# After relu2: torch.Size([64, 100])
# After fc3: torch.Size([64, 10])
# Logits: torch.Size([64, 10])

# %%
#输出模型的参数，及总参数量
for name, param in model.named_parameters():
    print(f"Name: {name}, Shape: {param.shape}, Number of params: {param.numel()}")
total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params}")
# Out:
# Name: fc1.weight, Shape: torch.Size([300, 784]), Number of params: 235200
# Name: fc1.bias, Shape: torch.Size([300]), Number of params: 300
# Name: fc2.weight, Shape: torch.Size([100, 300]), Number of params: 30000
# Name: fc2.bias, Shape: torch.Size([100]), Number of params: 100
# Name: fc3.weight, Shape: torch.Size([10, 100]), Number of params: 1000
# Name: fc3.bias, Shape: torch.Size([10]), Number of params: 10
# Total number of parameters: 266610

# %%
import torch.nn as nn
import torch.nn.init as init

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        layers = []
        input_dim = 28 * 28
        dropout_prob = 0.2  # Dropout rate, 可以调整
        
        # 第一层: Linear + SELU + Dropout
        linear = nn.Linear(input_dim, 100)
        init.xavier_uniform_(linear.weight)
        if linear.bias is not None:
            nn.init.zeros_(linear.bias)
        layers.append(linear)
        layers.append(nn.SELU())
        layers.append(nn.AlphaDropout(dropout_prob))  # 只在第一层加Dropout

        # 后续19个hidden layers (100, 100) 不加dropout
        for _ in range(19):
            linear = nn.Linear(100, 100)
            init.xavier_uniform_(linear.weight)
            if linear.bias is not None:
                nn.init.zeros_(linear.bias)
            layers.append(linear)
            layers.append(nn.SELU())
        
        self.hidden = nn.Sequential(*layers)
        self.output = nn.Linear(100, 10)
        init.xavier_uniform_(self.output.weight)
        if self.output.bias is not None:
            nn.init.zeros_(self.output.bias)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # 展平成(batch_size, 784)
        x = self.hidden(x)
        x = self.output(x)
        return x

# %%
model = NeuralNetwork()

# %%
import torch
import torch.optim as optim

# 判断设备：如果有GPU则用GPU，否则用CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 3. 设置交叉熵损失函数和SGD优化器
criterion = nn.CrossEntropyLoss()  # 默认求的是样本的平均损失
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
from model_train import Trainer
from importlib import reload
import model_train
reload(model_train)
from model_train import Trainer


# 将模型移至设备
model.to(device)

# 初始化Trainer，开启早停，并使用val_acc作为指标
trainer = Trainer(
    model, 
    train_loader, 
    val_loader, 
    lr=0.01, 
    momentum=0.9, 
    device=device, 
    early_stop=True,           # 启用早停
    early_stop_mode='val_acc', # 使用验证集准确率作为早停指标
    patience=5    ,             # 可自行调整容忍度
    save_path='dnn_dropout_model_pth'
)
trainer.train(epochs=30)

# 画出损失与准确率曲线
trainer.plot_metrics()
# Out:
# Epoch [1/30], Step [100/860], Loss: 0.9399
# Epoch [1/30], Step [200/860], Loss: 0.7205
# Epoch [1/30], Step [300/860], Loss: 0.6653
# Epoch [1/30], Step [400/860], Loss: 0.7681
# Epoch [1/30], Step [500/860], Loss: 0.6809
# Epoch [1/30], Step [600/860], Loss: 0.5271
# Epoch [1/30], Step [700/860], Loss: 0.6977
# Epoch [1/30], Step [800/860], Loss: 0.5306
# Epoch [1/30], Train Loss: 0.7076, Train Acc: 82.79%, Val Loss: 0.5468, Val Acc: 81.62%
# Best model saved at epoch 1.
# Epoch [2/30], Step [100/860], Loss: 0.8184
# Epoch [2/30], Step [200/860], Loss: 0.6327
# Epoch [2/30], Step [300/860], Loss: 0.4827
# Epoch [2/30], Step [400/860], Loss: 0.5661
# Epoch [2/30], Step [500/860], Loss: 0.3888
# Epoch [2/30], Step [600/860], Loss: 0.3714
# Epoch [2/30], Step [700/860], Loss: 0.5089
# Epoch [2/30], Step [800/860], Loss: 0.2110
# Epoch [2/30], Train Loss: 0.5092, Train Acc: 84.95%, Val Loss: 0.4824, Val Acc: 83.14%
# Best model saved at epoch 2.
# Epoch [3/30], Step [100/860], Loss: 0.2866
# Epoch [3/30], Step [200/860], Loss: 0.5984
# Epoch [3/30], Step [300/860], Loss: 0.4566
# Epoch [3/30], Step [400/860], Loss: 0.4357
# Epoch [3/30], Step [500/860], Loss: 0.3790
# Epoch [3/30], Step [600/860], Loss: 0.3864
# Epoch [3/30], Step [700/860], Loss: 0.6080
# Epoch [3/30], Step [800/860], Loss: 0.5650
# Epoch [3/30], Train Loss: 0.4521, Train Acc: 85.68%, Val Loss: 0.4573, Val Acc: 84.24%
# Best model saved at epoch 3.
# Epoch [4/30], Step [100/860], Loss: 0.5157
# Epoch [4/30], Step [200/860], Loss: 0.4408
# Epoch [4/30], Step [300/860], Loss: 0.4374
# Epoch [4/30], Step [400/860], Loss: 0.3776
# Epoch [4/30], Step [500/860], Loss: 0.4735
# Epoch [4/30], Step [600/860], Loss: 0.3089
# Epoch [4/30], Step [700/860], Loss: 0.2770
# Epoch [4/30], Step [800/860], Loss: 0.2668
# Epoch [4/30], Train Loss: 0.4224, Train Acc: 86.57%, Val Loss: 0.4175, Val Acc: 85.30%
# Best model saved at epoch 4.
# Epoch [5/30], Step [100/860], Loss: 0.3673
# Epoch [5/30], Step [200/860], Loss: 0.6250
# Epoch [5/30], Step [300/860], Loss: 0.4328
# Epoch [5/30], Step [400/860], Loss: 0.1454
# Epoch [5/30], Step [500/860], Loss: 0.4688
# Epoch [5/30], Step [600/860], Loss: 0.3078
# Epoch [5/30], Step [700/860], Loss: 0.5255
# Epoch [5/30], Step [800/860], Loss: 0.5648
# Epoch [5/30], Train Loss: 0.4029, Train Acc: 87.13%, Val Loss: 0.4447, Val Acc: 85.58%
# Best model saved at epoch 5.
# Epoch [6/30], Step [100/860], Loss: 0.5325
# Epoch [6/30], Step [200/860], Loss: 0.3243
# Epoch [6/30], Step [300/860], Loss: 0.4371
# Epoch [6/30], Step [400/860], Loss: 0.3446
# Epoch [6/30], Step [500/860], Loss: 0.3296
# Epoch [6/30], Step [600/860], Loss: 0.3524
# Epoch [6/30], Step [700/860], Loss: 0.4116
# Epoch [6/30], Step [800/860], Loss: 0.4389
# Epoch [6/30], Train Loss: 0.3855, Train Acc: 88.01%, Val Loss: 0.4044, Val Acc: 86.16%
# Best model saved at epoch 6.
# Epoch [7/30], Step [100/860], Loss: 0.3922
# Epoch [7/30], Step [200/860], Loss: 0.3680
# Epoch [7/30], Step [300/860], Loss: 0.2541
# Epoch [7/30], Step [400/860], Loss: 0.3005
# Epoch [7/30], Step [500/860], Loss: 0.3846
# Epoch [7/30], Step [600/860], Loss: 0.2323
# Epoch [7/30], Step [700/860], Loss: 0.1942
# Epoch [7/30], Step [800/860], Loss: 0.4625
# Epoch [7/30], Train Loss: 0.3732, Train Acc: 87.69%, Val Loss: 0.4060, Val Acc: 86.16%
# No improvement. Early stop counter: 1/5
# Epoch [8/30], Step [100/860], Loss: 0.4076
# Epoch [8/30], Step [200/860], Loss: 0.4353
# Epoch [8/30], Step [300/860], Loss: 0.4157
# Epoch [8/30], Step [400/860], Loss: 0.3884
# Epoch [8/30], Step [500/860], Loss: 0.5298
# Epoch [8/30], Step [600/860], Loss: 0.4589
# Epoch [8/30], Step [700/860], Loss: 0.5479
# Epoch [8/30], Step [800/860], Loss: 0.1887
# Epoch [8/30], Train Loss: 0.3604, Train Acc: 88.59%, Val Loss: 0.3804, Val Acc: 86.64%
# Best model saved at epoch 8.
# Epoch [9/30], Step [100/860], Loss: 0.4099
# Epoch [9/30], Step [200/860], Loss: 0.3492
# Epoch [9/30], Step [300/860], Loss: 0.3174
# Epoch [9/30], Step [400/860], Loss: 0.4062
# Epoch [9/30], Step [500/860], Loss: 0.2830
# Epoch [9/30], Step [600/860], Loss: 0.2975
# Epoch [9/30], Step [700/860], Loss: 0.3083
# Epoch [9/30], Step [800/860], Loss: 0.3565
# Epoch [9/30], Train Loss: 0.3528, Train Acc: 87.82%, Val Loss: 0.3960, Val Acc: 85.84%
# No improvement. Early stop counter: 1/5
# Epoch [10/30], Step [100/860], Loss: 0.3846
# Epoch [10/30], Step [200/860], Loss: 0.4073
# Epoch [10/30], Step [300/860], Loss: 0.3498
# Epoch [10/30], Step [400/860], Loss: 0.5216
# Epoch [10/30], Step [500/860], Loss: 0.2866
# Epoch [10/30], Step [600/860], Loss: 0.3014
# Epoch [10/30], Step [700/860], Loss: 0.4330
# Epoch [10/30], Step [800/860], Loss: 0.2958
# Epoch [10/30], Train Loss: 0.3424, Train Acc: 89.67%, Val Loss: 0.3716, Val Acc: 87.14%
# Best model saved at epoch 10.
# Epoch [11/30], Step [100/860], Loss: 0.6066
# Epoch [11/30], Step [200/860], Loss: 0.1809
# Epoch [11/30], Step [300/860], Loss: 0.4327
# Epoch [11/30], Step [400/860], Loss: 0.3331
# Epoch [11/30], Step [500/860], Loss: 0.3187
# Epoch [11/30], Step [600/860], Loss: 0.3614
# Epoch [11/30], Step [700/860], Loss: 0.2626
# Epoch [11/30], Step [800/860], Loss: 0.2692
# Epoch [11/30], Train Loss: 0.3361, Train Acc: 89.02%, Val Loss: 0.3702, Val Acc: 87.22%
# Best model saved at epoch 11.
# Epoch [12/30], Step [100/860], Loss: 0.3271
# Epoch [12/30], Step [200/860], Loss: 0.3096
# Epoch [12/30], Step [300/860], Loss: 0.5465
# Epoch [12/30], Step [400/860], Loss: 0.3083
# Epoch [12/30], Step [500/860], Loss: 0.2159
# Epoch [12/30], Step [600/860], Loss: 0.3537
# Epoch [12/30], Step [700/860], Loss: 0.3132
# Epoch [12/30], Step [800/860], Loss: 0.2284
# Epoch [12/30], Train Loss: 0.3252, Train Acc: 90.00%, Val Loss: 0.3608, Val Acc: 87.16%
# No improvement. Early stop counter: 1/5
# Epoch [13/30], Step [100/860], Loss: 0.4702
# Epoch [13/30], Step [200/860], Loss: 0.3455
# Epoch [13/30], Step [300/860], Loss: 0.2631
# Epoch [13/30], Step [400/860], Loss: 0.3106
# Epoch [13/30], Step [500/860], Loss: 0.5007
# Epoch [13/30], Step [600/860], Loss: 0.2630
# Epoch [13/30], Step [700/860], Loss: 0.1630
# Epoch [13/30], Step [800/860], Loss: 0.3998
# Epoch [13/30], Train Loss: 0.3235, Train Acc: 89.90%, Val Loss: 0.3686, Val Acc: 87.12%
# No improvement. Early stop counter: 2/5
# Epoch [14/30], Step [100/860], Loss: 0.5339
# Epoch [14/30], Step [200/860], Loss: 0.2250
# Epoch [14/30], Step [300/860], Loss: 0.2905
# Epoch [14/30], Step [400/860], Loss: 0.4047
# Epoch [14/30], Step [500/860], Loss: 0.1947
# Epoch [14/30], Step [600/860], Loss: 0.2953
# Epoch [14/30], Step [700/860], Loss: 0.2269
# Epoch [14/30], Step [800/860], Loss: 0.2520
# Epoch [14/30], Train Loss: 0.3158, Train Acc: 89.70%, Val Loss: 0.3641, Val Acc: 87.46%
# Best model saved at epoch 14.
# Epoch [15/30], Step [100/860], Loss: 0.2111
# Epoch [15/30], Step [200/860], Loss: 0.2689
# Epoch [15/30], Step [300/860], Loss: 0.2393
# Epoch [15/30], Step [400/860], Loss: 0.2737
# Epoch [15/30], Step [500/860], Loss: 0.2753
# Epoch [15/30], Step [600/860], Loss: 0.3779
# Epoch [15/30], Step [700/860], Loss: 0.2370
# Epoch [15/30], Step [800/860], Loss: 0.4182
# Epoch [15/30], Train Loss: 0.3093, Train Acc: 90.36%, Val Loss: 0.3534, Val Acc: 87.64%
# Best model saved at epoch 15.
# Epoch [16/30], Step [100/860], Loss: 0.2861
# Epoch [16/30], Step [200/860], Loss: 0.2744
# Epoch [16/30], Step [300/860], Loss: 0.4345
# Epoch [16/30], Step [400/860], Loss: 0.2919
# Epoch [16/30], Step [500/860], Loss: 0.3954
# Epoch [16/30], Step [600/860], Loss: 0.2925
# Epoch [16/30], Step [700/860], Loss: 0.1826
# Epoch [16/30], Step [800/860], Loss: 0.2302
# Epoch [16/30], Train Loss: 0.3038, Train Acc: 90.47%, Val Loss: 0.3560, Val Acc: 87.72%
# Best model saved at epoch 16.
# Epoch [17/30], Step [100/860], Loss: 0.2555
# Epoch [17/30], Step [200/860], Loss: 0.2458
# Epoch [17/30], Step [300/860], Loss: 0.3764
# Epoch [17/30], Step [400/860], Loss: 0.2285
# Epoch [17/30], Step [500/860], Loss: 0.3841
# Epoch [17/30], Step [600/860], Loss: 0.4033
# Epoch [17/30], Step [700/860], Loss: 0.2413
# Epoch [17/30], Step [800/860], Loss: 0.2738
# Epoch [17/30], Train Loss: 0.2993, Train Acc: 90.70%, Val Loss: 0.3480, Val Acc: 87.80%
# Best model saved at epoch 17.
# Epoch [18/30], Step [100/860], Loss: 0.2521
# Epoch [18/30], Step [200/860], Loss: 0.3069
# Epoch [18/30], Step [300/860], Loss: 0.3250
# Epoch [18/30], Step [400/860], Loss: 0.4628
# Epoch [18/30], Step [500/860], Loss: 0.3596
# Epoch [18/30], Step [600/860], Loss: 0.3785
# Epoch [18/30], Step [700/860], Loss: 0.2713
# Epoch [18/30], Step [800/860], Loss: 0.3739
# Epoch [18/30], Train Loss: 0.2928, Train Acc: 90.65%, Val Loss: 0.3549, Val Acc: 87.30%
# No improvement. Early stop counter: 1/5
# Epoch [19/30], Step [100/860], Loss: 0.2536
# Epoch [19/30], Step [200/860], Loss: 0.3421
# Epoch [19/30], Step [300/860], Loss: 0.1807
# Epoch [19/30], Step [400/860], Loss: 0.4313
# Epoch [19/30], Step [500/860], Loss: 0.3914
# Epoch [19/30], Step [600/860], Loss: 0.1845
# Epoch [19/30], Step [700/860], Loss: 0.1981
# Epoch [19/30], Step [800/860], Loss: 0.4062
# Epoch [19/30], Train Loss: 0.2905, Train Acc: 90.41%, Val Loss: 0.3562, Val Acc: 87.80%
# No improvement. Early stop counter: 2/5
# Epoch [20/30], Step [100/860], Loss: 0.2130
# Epoch [20/30], Step [200/860], Loss: 0.4648
# Epoch [20/30], Step [300/860], Loss: 0.3234
# Epoch [20/30], Step [400/860], Loss: 0.0945
# Epoch [20/30], Step [500/860], Loss: 0.3179
# Epoch [20/30], Step [600/860], Loss: 0.2397
# Epoch [20/30], Step [700/860], Loss: 0.4242
# Epoch [20/30], Step [800/860], Loss: 0.3153
# Epoch [20/30], Train Loss: 0.2887, Train Acc: 91.33%, Val Loss: 0.3453, Val Acc: 88.46%
# Best model saved at epoch 20.
# Epoch [21/30], Step [100/860], Loss: 0.2512
# Epoch [21/30], Step [200/860], Loss: 0.3237
# Epoch [21/30], Step [300/860], Loss: 0.1311
# Epoch [21/30], Step [400/860], Loss: 0.2812
# Epoch [21/30], Step [500/860], Loss: 0.4668
# Epoch [21/30], Step [600/860], Loss: 0.3276
# Epoch [21/30], Step [700/860], Loss: 0.2448
# Epoch [21/30], Step [800/860], Loss: 0.0925
# Epoch [21/30], Train Loss: 0.2822, Train Acc: 90.28%, Val Loss: 0.3773, Val Acc: 87.04%
# No improvement. Early stop counter: 1/5
# Epoch [22/30], Step [100/860], Loss: 0.3968
# Epoch [22/30], Step [200/860], Loss: 0.4346
# Epoch [22/30], Step [300/860], Loss: 0.3788
# Epoch [22/30], Step [400/860], Loss: 0.1722
# Epoch [22/30], Step [500/860], Loss: 0.3274
# Epoch [22/30], Step [600/860], Loss: 0.2351
# Epoch [22/30], Step [700/860], Loss: 0.2923
# Epoch [22/30], Step [800/860], Loss: 0.3240
# Epoch [22/30], Train Loss: 0.2778, Train Acc: 91.25%, Val Loss: 0.3537, Val Acc: 88.34%
# No improvement. Early stop counter: 2/5
# Epoch [23/30], Step [100/860], Loss: 0.1765
# Epoch [23/30], Step [200/860], Loss: 0.2129
# Epoch [23/30], Step [300/860], Loss: 0.4085
# Epoch [23/30], Step [400/860], Loss: 0.1543
# Epoch [23/30], Step [500/860], Loss: 0.1474
# Epoch [23/30], Step [600/860], Loss: 0.2922
# Epoch [23/30], Step [700/860], Loss: 0.1986
# Epoch [23/30], Step [800/860], Loss: 0.2634
# Epoch [23/30], Train Loss: 0.2743, Train Acc: 91.52%, Val Loss: 0.3420, Val Acc: 88.00%
# No improvement. Early stop counter: 3/5
# Epoch [24/30], Step [100/860], Loss: 0.5945
# Epoch [24/30], Step [200/860], Loss: 0.2432
# Epoch [24/30], Step [300/860], Loss: 0.2305
# Epoch [24/30], Step [400/860], Loss: 0.2845
# Epoch [24/30], Step [500/860], Loss: 0.2922
# Epoch [24/30], Step [600/860], Loss: 0.1279
# Epoch [24/30], Step [700/860], Loss: 0.3241
# Epoch [24/30], Step [800/860], Loss: 0.2911
# Epoch [24/30], Train Loss: 0.2686, Train Acc: 91.69%, Val Loss: 0.3367, Val Acc: 88.32%
# No improvement. Early stop counter: 4/5
# Epoch [25/30], Step [100/860], Loss: 0.1448
# Epoch [25/30], Step [200/860], Loss: 0.2494
# Epoch [25/30], Step [300/860], Loss: 0.3532
# Epoch [25/30], Step [400/860], Loss: 0.2868
# Epoch [25/30], Step [500/860], Loss: 0.2267
# Epoch [25/30], Step [600/860], Loss: 0.3808
# Epoch [25/30], Step [700/860], Loss: 0.2170
# Epoch [25/30], Step [800/860], Loss: 0.2250
# Epoch [25/30], Train Loss: 0.2669, Train Acc: 91.32%, Val Loss: 0.3632, Val Acc: 87.98%
# No improvement. Early stop counter: 5/5
# Early stopping at epoch 25. Best epoch was 20 with best_metric=88.4600
# Loading best model weights from epoch 20

# %%
# 在测试集上进行评估并画图

# 计算测试集上的准确率和损失
test_acc, test_loss = trainer.evaluating(test_loader)
print(f"Test Accuracy: {test_acc:.2f}%, Test Loss: {test_loss:.4f}")

# 可视化测试集上的预测结果
import matplotlib.pyplot as plt
import numpy as np

# 获取一组样本数据
dataiter = iter(test_loader)
images, labels = next(dataiter)
images, labels = images.to(device), labels.to(device)

# 模型预测
model.eval()
with torch.no_grad():
    outputs = model(images)
    _, predicted = torch.max(outputs, 1)

# 随机选取前10个样本进行可视化
fig = plt.figure(figsize=(15,4))
class_names = test_loader.dataset.classes if hasattr(test_loader.dataset, "classes") else [str(i) for i in range(10)]
for idx in range(10):
    ax = fig.add_subplot(2,5,idx+1)
    img = images[idx].cpu().numpy()
    # 若为灰度图，需要去掉channel维度
    if img.shape[0] == 1:
        img_show = img[0]
        plt.imshow(img_show, cmap="gray")
    else:
        img_show = np.transpose(img, (1,2,0))
        plt.imshow(img_show)
    ax.set_title(f"True: {class_names[labels[idx].item()]}\nPred: {class_names[predicted[idx].item()]}")
    plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Test Accuracy: 88.36%, Test Loss: 0.5298
