# %% [markdown]
# # fashion_minst分类实战

# %%
import torch
from torchvision import datasets, transforms

# 定义数据预处理
transform = transforms.Compose([
    transforms.ToTensor(),#将PIL.Image变换成torch.Tensor，并且将像素值归一化到[0,1]
    transforms.Normalize((0.285,), (0.352,)),  # 增加标准化
])

# 下载并加载训练数据集
full_train_dataset = datasets.FashionMNIST(root='./data', train=True, download=False, transform=transform)

# 从训练集中分出5000样本作为验证集
train_size = len(full_train_dataset) - 5000
val_size = 5000
#random_split打乱样本
generator = torch.Generator().manual_seed(42)
train_dataset, val_dataset = torch.utils.data.random_split(full_train_dataset, [train_size, val_size],generator=generator)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)  # batch_size是一个批次样本的数量
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=64, shuffle=False)

# 下载并加载测试数据集
test_dataset = datasets.FashionMNIST(root='./data', train=False, download=False, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
import matplotlib.pyplot as plt

# FashionMNIST类别名称
class_names = full_train_dataset.classes

# 可视化train_dataset前15个样本，并显示类别名称
fig, axs = plt.subplots(3, 5, figsize=(10, 6))
axs = axs.flatten()

for i in range(15):
    # 这里train_dataset[i]会返回(img, label)两个值，
    # img是第i个样本的图像（已做Tensor变换），label是对应的类别标签。
    # 因为train_dataset由torch.utils.data.random_split分割自原始的Dataset，继承了其__getitem__方法，原始FashionMNIST的__getitem__返回图像和标签两个值。
    img, label = train_dataset[i]
    img = img.squeeze().numpy()  # 变成2D numpy数组  将(1,28,28)压缩成(28,28)
    axs[i].imshow(img, cmap='gray')
    axs[i].set_title(class_names[label])
    axs[i].axis('off')

plt.tight_layout()
plt.show()

# %%
import torch.nn as nn

class ConvNet(nn.Module):
    def __init__(self):
        super().__init__()
        # 第一组卷积层：Conv1+Conv2+池化
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.selu1 = nn.SELU()
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        self.selu2 = nn.SELU()
        self.pool1 = nn.MaxPool2d(2, 2)
        # 第二组卷积层：Conv3+Conv4+池化
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.selu3 = nn.SELU()
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.selu4 = nn.SELU()
        self.pool2 = nn.MaxPool2d(2, 2)
        # 第三组卷积层：Conv5+Conv6+池化
        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.selu5 = nn.SELU()
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.selu6 = nn.SELU()
        self.pool3 = nn.MaxPool2d(2, 2)
        # 经过3次池化，每次尺寸减半：28->14->7->3(向下取整)
        self.fc1 = nn.Linear(128 * 3 * 3, 128)
        self.selu_fc1 = nn.SELU()
        self.fc2 = nn.Linear(128, 10)
        
    def forward(self, x):
        x = self.selu1(self.conv1(x))
        x = self.selu2(self.conv2(x))
        x = self.pool1(x)

        x = self.selu3(self.conv3(x))
        x = self.selu4(self.conv4(x))
        x = self.pool2(x)

        x = self.selu5(self.conv5(x))
        x = self.selu6(self.conv6(x))
        x = self.pool3(x)

        x = x.view(x.size(0), -1)
        x = self.selu_fc1(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
model = ConvNet()
# 随机生成一个输入数据，进行向前传播
import torch

# 假设输入为单张28x28的灰度图片，模拟batch size为1
dummy_input = torch.randn(4, 1, 28, 28)
# 将输入放到相应设备
dummy_input = dummy_input.to(next(model.parameters()).device)
# 向前传播
with torch.no_grad():
    output = model(dummy_input)
print("Output logits:", output.size())
# Out:
# Output logits: torch.Size([4, 10])

# %%
def count_parameters(model):
    """
    输出模型每层的参数量及总参数量
    """
    total_params = 0
    print("{:<30} {:<20}".format("Layer Name", "Num Params"))
    print("-" * 50)
    for name, param in model.named_parameters():
        if param.requires_grad:
            param_count = param.numel()
            print("{:<30} {:<20}".format(name, param_count))
            total_params += param_count
    print("-" * 50)
    print("Total parameters: {}".format(total_params))

# 计数、展示 ConvNet 各层参数量
count_parameters(model)
# Out:
# Layer Name                     Num Params
# --------------------------------------------------
# conv1.weight                   288
# conv1.bias                     32
# conv2.weight                   9216
# conv2.bias                     32
# conv3.weight                   18432
# conv3.bias                     64
# conv4.weight                   36864
# conv4.bias                     64
# conv5.weight                   73728
# conv5.bias                     128
# conv6.weight                   147456
# conv6.bias                     128
# fc1.weight                     147456
# fc1.bias                       128
# fc2.weight                     1280
# fc2.bias                       10
# --------------------------------------------------
# Total parameters: 435306

# %%
import torch
import torch.optim as optim

# 判断设备：如果有GPU则用GPU，否则用CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 3. 设置交叉熵损失函数和SGD优化器
criterion = nn.CrossEntropyLoss()  # 默认求的是样本的平均损失
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
from model_train import Trainer
import torch.optim as optim

# 将模型移至设备
model.to(device)

# 增加优化器
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
# 也可以换成其他优化器，比如 Adam，如果需要可以如下替换：
# optimizer = optim.Adam(model.parameters(), lr=0.001)

# 初始化Trainer，启用早停，并保存最佳模型
trainer = Trainer(
    model, 
    train_loader, 
    val_loader, 
    optimizer,     # 增加 optimizer 参数
    lr=0.01, 
    momentum=0.9, 
    device=device, 
    early_stop=True,              # 启用早停
    early_stop_mode='val_loss',   # 可选择 'val_loss' 或 'val_acc'
    patience=5,                   # 早停容忍轮数
    save_path='best_cnn_model_normalize.pth' # 保存模型的路径
)
trainer.train(epochs=20)

# 画出损失与准确率曲线
trainer.plot_metrics()
# Out:
# Epoch [1/20], Step [100/860], Loss: 0.5990
# Epoch [1/20], Step [200/860], Loss: 0.5286
# Epoch [1/20], Step [300/860], Loss: 0.4301
# Epoch [1/20], Step [400/860], Loss: 0.3517
# Epoch [1/20], Step [500/860], Loss: 0.2599
# Epoch [1/20], Step [600/860], Loss: 0.5184
# Epoch [1/20], Step [700/860], Loss: 0.5901
# Epoch [1/20], Step [800/860], Loss: 0.3122
# Epoch [1/20], Train Loss: 0.4677, Train Acc: 89.28%, Val Loss: 0.3220, Val Acc: 87.90%
# Best model saved at epoch 1.
# Epoch [2/20], Step [100/860], Loss: 0.2479
# Epoch [2/20], Step [200/860], Loss: 0.2679
# Epoch [2/20], Step [300/860], Loss: 0.4244
# Epoch [2/20], Step [400/860], Loss: 0.1654
# Epoch [2/20], Step [500/860], Loss: 0.2969
# Epoch [2/20], Step [600/860], Loss: 0.1329
# Epoch [2/20], Step [700/860], Loss: 0.2598
# Epoch [2/20], Step [800/860], Loss: 0.4732
# Epoch [2/20], Train Loss: 0.2806, Train Acc: 91.26%, Val Loss: 0.2764, Val Acc: 89.54%
# Best model saved at epoch 2.
# Epoch [3/20], Step [100/860], Loss: 0.2684
# Epoch [3/20], Step [200/860], Loss: 0.1606
# Epoch [3/20], Step [300/860], Loss: 0.2219
# Epoch [3/20], Step [400/860], Loss: 0.1042
# Epoch [3/20], Step [500/860], Loss: 0.5111
# Epoch [3/20], Step [600/860], Loss: 0.2464
# Epoch [3/20], Step [700/860], Loss: 0.1934
# Epoch [3/20], Step [800/860], Loss: 0.3590
# Epoch [3/20], Train Loss: 0.2281, Train Acc: 93.57%, Val Loss: 0.2274, Val Acc: 91.64%
# Best model saved at epoch 3.
# Epoch [4/20], Step [100/860], Loss: 0.0981
# Epoch [4/20], Step [200/860], Loss: 0.1378
# Epoch [4/20], Step [300/860], Loss: 0.2751
# Epoch [4/20], Step [400/860], Loss: 0.1168
# Epoch [4/20], Step [500/860], Loss: 0.3472
# Epoch [4/20], Step [600/860], Loss: 0.1669
# Epoch [4/20], Step [700/860], Loss: 0.2054
# Epoch [4/20], Step [800/860], Loss: 0.3750
# Epoch [4/20], Train Loss: 0.1981, Train Acc: 94.23%, Val Loss: 0.2260, Val Acc: 91.66%
# Best model saved at epoch 4.
# Epoch [5/20], Step [100/860], Loss: 0.0969
# Epoch [5/20], Step [200/860], Loss: 0.1296
# Epoch [5/20], Step [300/860], Loss: 0.1343
# Epoch [5/20], Step [400/860], Loss: 0.1579
# Epoch [5/20], Step [500/860], Loss: 0.1606
# Epoch [5/20], Step [600/860], Loss: 0.2461
# Epoch [5/20], Step [700/860], Loss: 0.0816
# Epoch [5/20], Step [800/860], Loss: 0.1566
# Epoch [5/20], Train Loss: 0.1721, Train Acc: 94.18%, Val Loss: 0.2288, Val Acc: 91.26%
# No improvement. Early stop counter: 1/5
# Epoch [6/20], Step [100/860], Loss: 0.1663
# Epoch [6/20], Step [200/860], Loss: 0.2485
# Epoch [6/20], Step [300/860], Loss: 0.1539
# Epoch [6/20], Step [400/860], Loss: 0.1169
# Epoch [6/20], Step [500/860], Loss: 0.1247
# Epoch [6/20], Step [600/860], Loss: 0.1111
# Epoch [6/20], Step [700/860], Loss: 0.0682
# Epoch [6/20], Step [800/860], Loss: 0.0420
# Epoch [6/20], Train Loss: 0.1512, Train Acc: 94.76%, Val Loss: 0.2560, Val Acc: 91.34%
# No improvement. Early stop counter: 2/5
# Epoch [7/20], Step [100/860], Loss: 0.1367
# Epoch [7/20], Step [200/860], Loss: 0.1405
# Epoch [7/20], Step [300/860], Loss: 0.0730
# Epoch [7/20], Step [400/860], Loss: 0.1380
# Epoch [7/20], Step [500/860], Loss: 0.1780
# Epoch [7/20], Step [600/860], Loss: 0.1500
# Epoch [7/20], Step [700/860], Loss: 0.1034
# Epoch [7/20], Step [800/860], Loss: 0.0903
# Epoch [7/20], Train Loss: 0.1297, Train Acc: 96.10%, Val Loss: 0.2303, Val Acc: 91.76%
# No improvement. Early stop counter: 3/5
# Epoch [8/20], Step [100/860], Loss: 0.1110
# Epoch [8/20], Step [200/860], Loss: 0.0780
# Epoch [8/20], Step [300/860], Loss: 0.0564
# Epoch [8/20], Step [400/860], Loss: 0.1297
# Epoch [8/20], Step [500/860], Loss: 0.1677
# Epoch [8/20], Step [600/860], Loss: 0.0914
# Epoch [8/20], Step [700/860], Loss: 0.0934
# Epoch [8/20], Step [800/860], Loss: 0.1281
# Epoch [8/20], Train Loss: 0.1130, Train Acc: 96.89%, Val Loss: 0.2448, Val Acc: 92.28%
# No improvement. Early stop counter: 4/5
# Epoch [9/20], Step [100/860], Loss: 0.0182
# Epoch [9/20], Step [200/860], Loss: 0.0068
# Epoch [9/20], Step [300/860], Loss: 0.1239
# Epoch [9/20], Step [400/860], Loss: 0.1211
# Epoch [9/20], Step [500/860], Loss: 0.1292
# Epoch [9/20], Step [600/860], Loss: 0.1182
# Epoch [9/20], Step [700/860], Loss: 0.1672
# Epoch [9/20], Step [800/860], Loss: 0.0706
# Epoch [9/20], Train Loss: 0.1022, Train Acc: 96.72%, Val Loss: 0.2466, Val Acc: 92.08%
# No improvement. Early stop counter: 5/5
# Early stopping at epoch 9. Best epoch was 4 with best_metric=0.2260
# Loading best model weights from epoch 4

# %%
# 在测试集进行评估
# 确保导入 trainer 有 test/evaluate 方法，或直接用 model 预测
# 先将模型设置为评估模式
model.eval()
test_loss = 0.0
correct = 0
total = 0

with torch.no_grad():
    for data, targets in test_loader:
        data, targets = data.to(device), targets.to(device)
        outputs = model(data)
        loss = criterion(outputs, targets)
        test_loss += loss.item() * data.size(0)
        _, predicted = torch.max(outputs, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()

test_loss = test_loss / total
accuracy = 100 * correct / total

print(f"Test Loss: {test_loss:.3f}")
print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
# Test Loss: 0.241
# Test Accuracy: 91.40%
