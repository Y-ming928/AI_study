# %% [markdown]
# # fashion_minst分类实战

# %%
import torch
from torchvision import datasets, transforms

# 定义数据预处理
transform = transforms.Compose([
    transforms.ToTensor(),#将PIL.Image变换成torch.Tensor，并且将像素值归一化到[0,1]
])

# 下载并加载训练数据集
full_train_dataset = datasets.FashionMNIST(root='./data', train=True, download=False, transform=transform)

# 从训练集中分出5000样本作为验证集
train_size = len(full_train_dataset) - 5000
val_size = 5000
#random_split打乱样本
generator = torch.Generator().manual_seed(42)
train_dataset, val_dataset = torch.utils.data.random_split(full_train_dataset, [train_size, val_size],generator=generator)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)  # batch_size是一个批次样本的数量
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=64, shuffle=False)

# 下载并加载测试数据集
test_dataset = datasets.FashionMNIST(root='./data', train=False, download=False, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
import matplotlib.pyplot as plt

# FashionMNIST类别名称
class_names = full_train_dataset.classes

# 可视化train_dataset前15个样本，并显示类别名称
fig, axs = plt.subplots(3, 5, figsize=(10, 6))
axs = axs.flatten()

for i in range(15):
    # 这里train_dataset[i]会返回(img, label)两个值，
    # img是第i个样本的图像（已做Tensor变换），label是对应的类别标签。
    # 因为train_dataset由torch.utils.data.random_split分割自原始的Dataset，继承了其__getitem__方法，原始FashionMNIST的__getitem__返回图像和标签两个值。
    img, label = train_dataset[i]
    img = img.squeeze().numpy()  # 变成2D numpy数组  将(1,28,28)压缩成(28,28)
    axs[i].imshow(img, cmap='gray')
    axs[i].set_title(class_names[label])
    axs[i].axis('off')

plt.tight_layout()
plt.show()

# %%
import torch.nn as nn

class ConvNet(nn.Module):
    def __init__(self):
        super().__init__()
        # 第一组卷积层：Conv1+Conv2+池化
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        # 第二组卷积层：Conv3+Conv4+池化
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.relu4 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        # 第三组卷积层：Conv5+Conv6+池化
        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.relu5 = nn.ReLU()
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.relu6 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(2, 2)
        # 经过3次池化，每次尺寸减半：28->14->7->3(向下取整)
        self.fc1 = nn.Linear(128 * 3 * 3, 128)
        self.relu_fc1 = nn.ReLU()
        self.fc2 = nn.Linear(128, 10)
        
    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        x = self.pool1(x)

        x = self.relu3(self.conv3(x))
        x = self.relu4(self.conv4(x))
        x = self.pool2(x)

        x = self.relu5(self.conv5(x))
        x = self.relu6(self.conv6(x))
        x = self.pool3(x)

        x = x.view(x.size(0), -1)
        x = self.relu_fc1(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
model = ConvNet()
# 随机生成一个输入数据，进行向前传播
import torch

# 假设输入为单张28x28的灰度图片，模拟batch size为1
dummy_input = torch.randn(4, 1, 28, 28)
# 将输入放到相应设备
dummy_input = dummy_input.to(next(model.parameters()).device)
# 向前传播
with torch.no_grad():
    output = model(dummy_input)
print("Output logits:", output.size())
# Out:
# Output logits: torch.Size([4, 10])

# %%
def count_parameters(model):
    """
    输出模型每层的参数量及总参数量
    """
    total_params = 0
    print("{:<30} {:<20}".format("Layer Name", "Num Params"))
    print("-" * 50)
    for name, param in model.named_parameters():
        if param.requires_grad:
            param_count = param.numel()
            print("{:<30} {:<20}".format(name, param_count))
            total_params += param_count
    print("-" * 50)
    print("Total parameters: {}".format(total_params))

# 计数、展示 ConvNet 各层参数量
count_parameters(model)
# Out:
# Layer Name                     Num Params
# --------------------------------------------------
# conv1.weight                   288
# conv1.bias                     32
# conv2.weight                   9216
# conv2.bias                     32
# conv3.weight                   18432
# conv3.bias                     64
# conv4.weight                   36864
# conv4.bias                     64
# conv5.weight                   73728
# conv5.bias                     128
# conv6.weight                   147456
# conv6.bias                     128
# fc1.weight                     147456
# fc1.bias                       128
# fc2.weight                     1280
# fc2.bias                       10
# --------------------------------------------------
# Total parameters: 435306

# %%
import torch
import torch.optim as optim

# 判断设备：如果有GPU则用GPU，否则用CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 3. 设置交叉熵损失函数和SGD优化器
criterion = nn.CrossEntropyLoss()  # 默认求的是样本的平均损失
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
from model_train import Trainer
import torch.optim as optim

# 将模型移至设备
model.to(device)

# 增加优化器
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
# 也可以换成其他优化器，比如 Adam，如果需要可以如下替换：
# optimizer = optim.Adam(model.parameters(), lr=0.001)

# 初始化Trainer，启用早停，并保存最佳模型
trainer = Trainer(
    model, 
    train_loader, 
    val_loader, 
    optimizer,     # 增加 optimizer 参数
    lr=0.01, 
    momentum=0.9, 
    device=device, 
    early_stop=True,              # 启用早停
    early_stop_mode='val_loss',   # 可选择 'val_loss' 或 'val_acc'
    patience=5,                   # 早停容忍轮数
    save_path='best_cnn_model.pth' # 保存模型的路径
)
trainer.train(epochs=20)

# 画出损失与准确率曲线
trainer.plot_metrics()
# Out:
# Epoch [1/20], Step [100/860], Loss: 2.3045
# Epoch [1/20], Step [200/860], Loss: 2.2923
# Epoch [1/20], Step [300/860], Loss: 1.2018
# Epoch [1/20], Step [400/860], Loss: 0.8948
# Epoch [1/20], Step [500/860], Loss: 0.7081
# Epoch [1/20], Step [600/860], Loss: 0.5629
# Epoch [1/20], Step [700/860], Loss: 0.7512
# Epoch [1/20], Step [800/860], Loss: 0.5369
# Epoch [1/20], Train Loss: 1.1782, Train Acc: 81.53%, Val Loss: 0.5309, Val Acc: 80.84%
# Best model saved at epoch 1.
# Epoch [2/20], Step [100/860], Loss: 0.4132
# Epoch [2/20], Step [200/860], Loss: 0.5269
# Epoch [2/20], Step [300/860], Loss: 0.5587
# Epoch [2/20], Step [400/860], Loss: 0.5778
# Epoch [2/20], Step [500/860], Loss: 0.3872
# Epoch [2/20], Step [600/860], Loss: 0.2921
# Epoch [2/20], Step [700/860], Loss: 0.4986
# Epoch [2/20], Step [800/860], Loss: 0.2361
# Epoch [2/20], Train Loss: 0.4075, Train Acc: 87.14%, Val Loss: 0.3795, Val Acc: 85.64%
# Best model saved at epoch 2.
# Epoch [3/20], Step [100/860], Loss: 0.4179
# Epoch [3/20], Step [200/860], Loss: 0.2221
# Epoch [3/20], Step [300/860], Loss: 0.4007
# Epoch [3/20], Step [400/860], Loss: 0.2864
# Epoch [3/20], Step [500/860], Loss: 0.2200
# Epoch [3/20], Step [600/860], Loss: 0.4335
# Epoch [3/20], Step [700/860], Loss: 0.2330
# Epoch [3/20], Step [800/860], Loss: 0.2282
# Epoch [3/20], Train Loss: 0.3346, Train Acc: 88.37%, Val Loss: 0.3402, Val Acc: 87.44%
# Best model saved at epoch 3.
# Epoch [4/20], Step [100/860], Loss: 0.1663
# Epoch [4/20], Step [200/860], Loss: 0.2601
# Epoch [4/20], Step [300/860], Loss: 0.0827
# Epoch [4/20], Step [400/860], Loss: 0.2633
# Epoch [4/20], Step [500/860], Loss: 0.2113
# Epoch [4/20], Step [600/860], Loss: 0.2170
# Epoch [4/20], Step [700/860], Loss: 0.2307
# Epoch [4/20], Step [800/860], Loss: 0.3734
# Epoch [4/20], Train Loss: 0.2954, Train Acc: 90.21%, Val Loss: 0.2924, Val Acc: 88.90%
# Best model saved at epoch 4.
# Epoch [5/20], Step [100/860], Loss: 0.2139
# Epoch [5/20], Step [200/860], Loss: 0.2743
# Epoch [5/20], Step [300/860], Loss: 0.1997
# Epoch [5/20], Step [400/860], Loss: 0.2339
# Epoch [5/20], Step [500/860], Loss: 0.2774
# Epoch [5/20], Step [600/860], Loss: 0.5322
# Epoch [5/20], Step [700/860], Loss: 0.2635
# Epoch [5/20], Step [800/860], Loss: 0.2826
# Epoch [5/20], Train Loss: 0.2660, Train Acc: 91.24%, Val Loss: 0.2792, Val Acc: 89.88%
# Best model saved at epoch 5.
# Epoch [6/20], Step [100/860], Loss: 0.2000
# Epoch [6/20], Step [200/860], Loss: 0.2572
# Epoch [6/20], Step [300/860], Loss: 0.3247
# Epoch [6/20], Step [400/860], Loss: 0.3033
# Epoch [6/20], Step [500/860], Loss: 0.1922
# Epoch [6/20], Step [600/860], Loss: 0.2401
# Epoch [6/20], Step [700/860], Loss: 0.3505
# Epoch [6/20], Step [800/860], Loss: 0.1959
# Epoch [6/20], Train Loss: 0.2447, Train Acc: 92.26%, Val Loss: 0.2571, Val Acc: 90.36%
# Best model saved at epoch 6.
# Epoch [7/20], Step [100/860], Loss: 0.4042
# Epoch [7/20], Step [200/860], Loss: 0.1919
# Epoch [7/20], Step [300/860], Loss: 0.2514
# Epoch [7/20], Step [400/860], Loss: 0.3141
# Epoch [7/20], Step [500/860], Loss: 0.1651
# Epoch [7/20], Step [600/860], Loss: 0.1653
# Epoch [7/20], Step [700/860], Loss: 0.1011
# Epoch [7/20], Step [800/860], Loss: 0.3170
# Epoch [7/20], Train Loss: 0.2239, Train Acc: 92.52%, Val Loss: 0.2536, Val Acc: 90.34%
# Best model saved at epoch 7.
# Epoch [8/20], Step [100/860], Loss: 0.0959
# Epoch [8/20], Step [200/860], Loss: 0.2979
# Epoch [8/20], Step [300/860], Loss: 0.2155
# Epoch [8/20], Step [400/860], Loss: 0.1209
# Epoch [8/20], Step [500/860], Loss: 0.1909
# Epoch [8/20], Step [600/860], Loss: 0.2005
# Epoch [8/20], Step [700/860], Loss: 0.1508
# Epoch [8/20], Step [800/860], Loss: 0.2066
# Epoch [8/20], Train Loss: 0.2090, Train Acc: 92.98%, Val Loss: 0.2489, Val Acc: 90.54%
# Best model saved at epoch 8.
# Epoch [9/20], Step [100/860], Loss: 0.1862
# Epoch [9/20], Step [200/860], Loss: 0.2349
# Epoch [9/20], Step [300/860], Loss: 0.1048
# Epoch [9/20], Step [400/860], Loss: 0.1614
# Epoch [9/20], Step [500/860], Loss: 0.1154
# Epoch [9/20], Step [600/860], Loss: 0.2470
# Epoch [9/20], Step [700/860], Loss: 0.3247
# Epoch [9/20], Step [800/860], Loss: 0.0843
# Epoch [9/20], Train Loss: 0.1941, Train Acc: 93.19%, Val Loss: 0.2528, Val Acc: 90.38%
# No improvement. Early stop counter: 1/5
# Epoch [10/20], Step [100/860], Loss: 0.2385
# Epoch [10/20], Step [200/860], Loss: 0.2505
# Epoch [10/20], Step [300/860], Loss: 0.1340
# Epoch [10/20], Step [400/860], Loss: 0.1666
# Epoch [10/20], Step [500/860], Loss: 0.2465
# Epoch [10/20], Step [600/860], Loss: 0.1108
# Epoch [10/20], Step [700/860], Loss: 0.1512
# Epoch [10/20], Step [800/860], Loss: 0.1127
# Epoch [10/20], Train Loss: 0.1842, Train Acc: 94.13%, Val Loss: 0.2372, Val Acc: 91.20%
# Best model saved at epoch 10.
# Epoch [11/20], Step [100/860], Loss: 0.1361
# Epoch [11/20], Step [200/860], Loss: 0.1156
# Epoch [11/20], Step [300/860], Loss: 0.1834
# Epoch [11/20], Step [400/860], Loss: 0.2285
# Epoch [11/20], Step [500/860], Loss: 0.1563
# Epoch [11/20], Step [600/860], Loss: 0.1452
# Epoch [11/20], Step [700/860], Loss: 0.1530
# Epoch [11/20], Step [800/860], Loss: 0.1258
# Epoch [11/20], Train Loss: 0.1699, Train Acc: 94.15%, Val Loss: 0.2408, Val Acc: 91.60%
# No improvement. Early stop counter: 1/5
# Epoch [12/20], Step [100/860], Loss: 0.1255
# Epoch [12/20], Step [200/860], Loss: 0.1657
# Epoch [12/20], Step [300/860], Loss: 0.2845
# Epoch [12/20], Step [400/860], Loss: 0.2636
# Epoch [12/20], Step [500/860], Loss: 0.3589
# Epoch [12/20], Step [600/860], Loss: 0.1459
# Epoch [12/20], Step [700/860], Loss: 0.0882
# Epoch [12/20], Step [800/860], Loss: 0.1701
# Epoch [12/20], Train Loss: 0.1599, Train Acc: 94.01%, Val Loss: 0.2525, Val Acc: 90.82%
# No improvement. Early stop counter: 2/5
# Epoch [13/20], Step [100/860], Loss: 0.1736
# Epoch [13/20], Step [200/860], Loss: 0.1994
# Epoch [13/20], Step [300/860], Loss: 0.0734
# Epoch [13/20], Step [400/860], Loss: 0.1565
# Epoch [13/20], Step [500/860], Loss: 0.1309
# Epoch [13/20], Step [600/860], Loss: 0.1723
# Epoch [13/20], Step [700/860], Loss: 0.1306
# Epoch [13/20], Step [800/860], Loss: 0.1867
# Epoch [13/20], Train Loss: 0.1496, Train Acc: 95.19%, Val Loss: 0.2354, Val Acc: 91.50%
# Best model saved at epoch 13.
# Epoch [14/20], Step [100/860], Loss: 0.2257
# Epoch [14/20], Step [200/860], Loss: 0.1153
# Epoch [14/20], Step [300/860], Loss: 0.2165
# Epoch [14/20], Step [400/860], Loss: 0.1288
# Epoch [14/20], Step [500/860], Loss: 0.1511
# Epoch [14/20], Step [600/860], Loss: 0.0631
# Epoch [14/20], Step [700/860], Loss: 0.0445
# Epoch [14/20], Step [800/860], Loss: 0.1862
# Epoch [14/20], Train Loss: 0.1359, Train Acc: 95.10%, Val Loss: 0.2484, Val Acc: 91.44%
# No improvement. Early stop counter: 1/5
# Epoch [15/20], Step [100/860], Loss: 0.0779
# Epoch [15/20], Step [200/860], Loss: 0.1161
# Epoch [15/20], Step [300/860], Loss: 0.0308
# Epoch [15/20], Step [400/860], Loss: 0.1199
# Epoch [15/20], Step [500/860], Loss: 0.1640
# Epoch [15/20], Step [600/860], Loss: 0.1590
# Epoch [15/20], Step [700/860], Loss: 0.1605
# Epoch [15/20], Step [800/860], Loss: 0.0685
# Epoch [15/20], Train Loss: 0.1287, Train Acc: 96.20%, Val Loss: 0.2400, Val Acc: 91.80%
# No improvement. Early stop counter: 2/5
# Epoch [16/20], Step [100/860], Loss: 0.0652
# Epoch [16/20], Step [200/860], Loss: 0.0562
# Epoch [16/20], Step [300/860], Loss: 0.0419
# Epoch [16/20], Step [400/860], Loss: 0.2161
# Epoch [16/20], Step [500/860], Loss: 0.1602
# Epoch [16/20], Step [600/860], Loss: 0.1279
# Epoch [16/20], Step [700/860], Loss: 0.1896
# Epoch [16/20], Step [800/860], Loss: 0.1693
# Epoch [16/20], Train Loss: 0.1175, Train Acc: 96.23%, Val Loss: 0.2485, Val Acc: 91.70%
# No improvement. Early stop counter: 3/5
# Epoch [17/20], Step [100/860], Loss: 0.1043
# Epoch [17/20], Step [200/860], Loss: 0.1331
# Epoch [17/20], Step [300/860], Loss: 0.1305
# Epoch [17/20], Step [400/860], Loss: 0.2866
# Epoch [17/20], Step [500/860], Loss: 0.0404
# Epoch [17/20], Step [600/860], Loss: 0.1275
# Epoch [17/20], Step [700/860], Loss: 0.0955
# Epoch [17/20], Step [800/860], Loss: 0.2128
# Epoch [17/20], Train Loss: 0.1111, Train Acc: 96.72%, Val Loss: 0.2533, Val Acc: 91.38%
# No improvement. Early stop counter: 4/5
# Epoch [18/20], Step [100/860], Loss: 0.1052
# Epoch [18/20], Step [200/860], Loss: 0.1174
# Epoch [18/20], Step [300/860], Loss: 0.1923
# Epoch [18/20], Step [400/860], Loss: 0.0430
# Epoch [18/20], Step [500/860], Loss: 0.0878
# Epoch [18/20], Step [600/860], Loss: 0.1058
# Epoch [18/20], Step [700/860], Loss: 0.0455
# Epoch [18/20], Step [800/860], Loss: 0.1189
# Epoch [18/20], Train Loss: 0.1026, Train Acc: 97.15%, Val Loss: 0.2636, Val Acc: 91.62%
# No improvement. Early stop counter: 5/5
# Early stopping at epoch 18. Best epoch was 13 with best_metric=0.2354
# Loading best model weights from epoch 13

# %%
# 在测试集进行评估
# 确保导入 trainer 有 test/evaluate 方法，或直接用 model 预测
# 先将模型设置为评估模式
model.eval()
test_loss = 0.0
correct = 0
total = 0

with torch.no_grad():
    for data, targets in test_loader:
        data, targets = data.to(device), targets.to(device)
        outputs = model(data)
        loss = criterion(outputs, targets)
        test_loss += loss.item() * data.size(0)
        _, predicted = torch.max(outputs, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()

test_loss = test_loss / total
accuracy = 100 * correct / total

print(f"Test Loss: {test_loss:.3f}")
print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
# Test Loss: 0.253
# Test Accuracy: 91.22%
