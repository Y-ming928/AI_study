# %% [markdown]
# # fashion_minst分类实战

# %%
import torch
from torchvision import datasets, transforms

# 定义数据预处理
transform = transforms.Compose([
    transforms.ToTensor(),#将PIL.Image变换成torch.Tensor，并且将像素值归一化到[0,1]
    transforms.Normalize((0.285,), (0.352,)),  # 增加标准化
])

# 下载并加载训练数据集
full_train_dataset = datasets.FashionMNIST(root='./data', train=True, download=False, transform=transform)

# 从训练集中分出5000样本作为验证集
train_size = len(full_train_dataset) - 5000
val_size = 5000
#random_split打乱样本
generator = torch.Generator().manual_seed(42)
train_dataset, val_dataset = torch.utils.data.random_split(full_train_dataset, [train_size, val_size],generator=generator)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)  # batch_size是一个批次样本的数量
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=64, shuffle=False)

# 下载并加载测试数据集
test_dataset = datasets.FashionMNIST(root='./data', train=False, download=False, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
import matplotlib.pyplot as plt

# FashionMNIST类别名称
class_names = full_train_dataset.classes

# 可视化train_dataset前15个样本，并显示类别名称
fig, axs = plt.subplots(3, 5, figsize=(10, 6))
axs = axs.flatten()

for i in range(15):
    # 这里train_dataset[i]会返回(img, label)两个值，
    # img是第i个样本的图像（已做Tensor变换），label是对应的类别标签。
    # 因为train_dataset由torch.utils.data.random_split分割自原始的Dataset，继承了其__getitem__方法，原始FashionMNIST的__getitem__返回图像和标签两个值。
    img, label = train_dataset[i]
    img = img.squeeze().numpy()  # 变成2D numpy数组  将(1,28,28)压缩成(28,28)
    axs[i].imshow(img, cmap='gray')
    axs[i].set_title(class_names[label])
    axs[i].axis('off')

plt.tight_layout()
plt.show()

# %%
import torch.nn as nn

class ConvNet(nn.Module):
    def __init__(self):
        super().__init__()
        # 第一组卷积层：Conv1+Conv2+池化
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        # 第二组卷积层：Conv3+Conv4+池化
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.relu4 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        # 第三组卷积层：Conv5+Conv6+池化
        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.relu5 = nn.ReLU()
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.relu6 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(2, 2)
        # 经过3次池化，每次尺寸减半：28->14->7->3(向下取整)
        self.fc1 = nn.Linear(128 * 3 * 3, 128)
        self.relu_fc1 = nn.ReLU()
        self.fc2 = nn.Linear(128, 10)
        
    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        x = self.pool1(x)

        x = self.relu3(self.conv3(x))
        x = self.relu4(self.conv4(x))
        x = self.pool2(x)

        x = self.relu5(self.conv5(x))
        x = self.relu6(self.conv6(x))
        x = self.pool3(x)

        x = x.view(x.size(0), -1)
        x = self.relu_fc1(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
model = ConvNet()
# 随机生成一个输入数据，进行向前传播
import torch

# 假设输入为单张28x28的灰度图片，模拟batch size为1
dummy_input = torch.randn(4, 1, 28, 28)
# 将输入放到相应设备
dummy_input = dummy_input.to(next(model.parameters()).device)
# 向前传播
with torch.no_grad():
    output = model(dummy_input)
print("Output logits:", output.size())
# Out:
# Output logits: torch.Size([4, 10])

# %%
def count_parameters(model):
    """
    输出模型每层的参数量及总参数量
    """
    total_params = 0
    print("{:<30} {:<20}".format("Layer Name", "Num Params"))
    print("-" * 50)
    for name, param in model.named_parameters():
        if param.requires_grad:
            param_count = param.numel()
            print("{:<30} {:<20}".format(name, param_count))
            total_params += param_count
    print("-" * 50)
    print("Total parameters: {}".format(total_params))

# 计数、展示 ConvNet 各层参数量
count_parameters(model)
# Out:
# Layer Name                     Num Params
# --------------------------------------------------
# conv1.weight                   288
# conv1.bias                     32
# conv2.weight                   9216
# conv2.bias                     32
# conv3.weight                   18432
# conv3.bias                     64
# conv4.weight                   36864
# conv4.bias                     64
# conv5.weight                   73728
# conv5.bias                     128
# conv6.weight                   147456
# conv6.bias                     128
# fc1.weight                     147456
# fc1.bias                       128
# fc2.weight                     1280
# fc2.bias                       10
# --------------------------------------------------
# Total parameters: 435306

# %%
import torch
import torch.optim as optim

# 判断设备：如果有GPU则用GPU，否则用CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 3. 设置交叉熵损失函数和SGD优化器
criterion = nn.CrossEntropyLoss()  # 默认求的是样本的平均损失
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
from model_train import Trainer
import torch.optim as optim

# 将模型移至设备
model.to(device)

# 增加优化器
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
# 也可以换成其他优化器，比如 Adam，如果需要可以如下替换：
# optimizer = optim.Adam(model.parameters(), lr=0.001)

# 初始化Trainer，启用早停，并保存最佳模型
trainer = Trainer(
    model, 
    train_loader, 
    val_loader, 
    optimizer,     # 增加 optimizer 参数
    lr=0.01, 
    momentum=0.9, 
    device=device, 
    early_stop=True,              # 启用早停
    early_stop_mode='val_loss',   # 可选择 'val_loss' 或 'val_acc'
    patience=5,                   # 早停容忍轮数
    save_path='best_cnn_model_normalize.pth' # 保存模型的路径
)
trainer.train(epochs=20)

# 画出损失与准确率曲线
trainer.plot_metrics()
# Out:
# Epoch [1/20], Step [100/860], Loss: 2.2942
# Epoch [1/20], Step [200/860], Loss: 1.4272
# Epoch [1/20], Step [300/860], Loss: 0.7659
# Epoch [1/20], Step [400/860], Loss: 0.8662
# Epoch [1/20], Step [500/860], Loss: 0.7164
# Epoch [1/20], Step [600/860], Loss: 0.3560
# Epoch [1/20], Step [700/860], Loss: 0.5187
# Epoch [1/20], Step [800/860], Loss: 0.7354
# Epoch [1/20], Train Loss: 0.9745, Train Acc: 84.97%, Val Loss: 0.4214, Val Acc: 84.10%
# Best model saved at epoch 1.
# Epoch [2/20], Step [100/860], Loss: 0.4535
# Epoch [2/20], Step [200/860], Loss: 0.4718
# Epoch [2/20], Step [300/860], Loss: 0.4276
# Epoch [2/20], Step [400/860], Loss: 0.3047
# Epoch [2/20], Step [500/860], Loss: 0.4722
# Epoch [2/20], Step [600/860], Loss: 0.4170
# Epoch [2/20], Step [700/860], Loss: 0.3048
# Epoch [2/20], Step [800/860], Loss: 0.2927
# Epoch [2/20], Train Loss: 0.3704, Train Acc: 88.30%, Val Loss: 0.3514, Val Acc: 87.14%
# Best model saved at epoch 2.
# Epoch [3/20], Step [100/860], Loss: 0.2974
# Epoch [3/20], Step [200/860], Loss: 0.3223
# Epoch [3/20], Step [300/860], Loss: 0.1984
# Epoch [3/20], Step [400/860], Loss: 0.3080
# Epoch [3/20], Step [500/860], Loss: 0.3193
# Epoch [3/20], Step [600/860], Loss: 0.1692
# Epoch [3/20], Step [700/860], Loss: 0.6013
# Epoch [3/20], Step [800/860], Loss: 0.4203
# Epoch [3/20], Train Loss: 0.3115, Train Acc: 90.17%, Val Loss: 0.3048, Val Acc: 88.96%
# Best model saved at epoch 3.
# Epoch [4/20], Step [100/860], Loss: 0.3791
# Epoch [4/20], Step [200/860], Loss: 0.2500
# Epoch [4/20], Step [300/860], Loss: 0.1894
# Epoch [4/20], Step [400/860], Loss: 0.3037
# Epoch [4/20], Step [500/860], Loss: 0.3154
# Epoch [4/20], Step [600/860], Loss: 0.1886
# Epoch [4/20], Step [700/860], Loss: 0.3911
# Epoch [4/20], Step [800/860], Loss: 0.2407
# Epoch [4/20], Train Loss: 0.2707, Train Acc: 91.36%, Val Loss: 0.2771, Val Acc: 89.74%
# Best model saved at epoch 4.
# Epoch [5/20], Step [100/860], Loss: 0.3704
# Epoch [5/20], Step [200/860], Loss: 0.0957
# Epoch [5/20], Step [300/860], Loss: 0.2009
# Epoch [5/20], Step [400/860], Loss: 0.2121
# Epoch [5/20], Step [500/860], Loss: 0.1722
# Epoch [5/20], Step [600/860], Loss: 0.2093
# Epoch [5/20], Step [700/860], Loss: 0.1424
# Epoch [5/20], Step [800/860], Loss: 0.1962
# Epoch [5/20], Train Loss: 0.2430, Train Acc: 92.13%, Val Loss: 0.2657, Val Acc: 89.72%
# Best model saved at epoch 5.
# Epoch [6/20], Step [100/860], Loss: 0.3017
# Epoch [6/20], Step [200/860], Loss: 0.1740
# Epoch [6/20], Step [300/860], Loss: 0.1819
# Epoch [6/20], Step [400/860], Loss: 0.2534
# Epoch [6/20], Step [500/860], Loss: 0.1482
# Epoch [6/20], Step [600/860], Loss: 0.3375
# Epoch [6/20], Step [700/860], Loss: 0.1899
# Epoch [6/20], Step [800/860], Loss: 0.1742
# Epoch [6/20], Train Loss: 0.2187, Train Acc: 92.93%, Val Loss: 0.2478, Val Acc: 90.54%
# Best model saved at epoch 6.
# Epoch [7/20], Step [100/860], Loss: 0.2330
# Epoch [7/20], Step [200/860], Loss: 0.1452
# Epoch [7/20], Step [300/860], Loss: 0.2057
# Epoch [7/20], Step [400/860], Loss: 0.1985
# Epoch [7/20], Step [500/860], Loss: 0.1301
# Epoch [7/20], Step [600/860], Loss: 0.2563
# Epoch [7/20], Step [700/860], Loss: 0.1525
# Epoch [7/20], Step [800/860], Loss: 0.1422
# Epoch [7/20], Train Loss: 0.2016, Train Acc: 93.19%, Val Loss: 0.2615, Val Acc: 90.50%
# No improvement. Early stop counter: 1/5
# Epoch [8/20], Step [100/860], Loss: 0.0777
# Epoch [8/20], Step [200/860], Loss: 0.1248
# Epoch [8/20], Step [300/860], Loss: 0.3314
# Epoch [8/20], Step [400/860], Loss: 0.2581
# Epoch [8/20], Step [500/860], Loss: 0.0969
# Epoch [8/20], Step [600/860], Loss: 0.1768
# Epoch [8/20], Step [700/860], Loss: 0.1537
# Epoch [8/20], Step [800/860], Loss: 0.0902
# Epoch [8/20], Train Loss: 0.1847, Train Acc: 94.41%, Val Loss: 0.2308, Val Acc: 91.44%
# Best model saved at epoch 8.
# Epoch [9/20], Step [100/860], Loss: 0.0866
# Epoch [9/20], Step [200/860], Loss: 0.2001
# Epoch [9/20], Step [300/860], Loss: 0.2858
# Epoch [9/20], Step [400/860], Loss: 0.1143
# Epoch [9/20], Step [500/860], Loss: 0.1945
# Epoch [9/20], Step [600/860], Loss: 0.1601
# Epoch [9/20], Step [700/860], Loss: 0.1325
# Epoch [9/20], Step [800/860], Loss: 0.0961
# Epoch [9/20], Train Loss: 0.1701, Train Acc: 94.29%, Val Loss: 0.2439, Val Acc: 91.38%
# No improvement. Early stop counter: 1/5
# Epoch [10/20], Step [100/860], Loss: 0.1361
# Epoch [10/20], Step [200/860], Loss: 0.1515
# Epoch [10/20], Step [300/860], Loss: 0.1961
# Epoch [10/20], Step [400/860], Loss: 0.1836
# Epoch [10/20], Step [500/860], Loss: 0.1511
# Epoch [10/20], Step [600/860], Loss: 0.1297
# Epoch [10/20], Step [700/860], Loss: 0.1208
# Epoch [10/20], Step [800/860], Loss: 0.2215
# Epoch [10/20], Train Loss: 0.1559, Train Acc: 95.13%, Val Loss: 0.2429, Val Acc: 91.28%
# No improvement. Early stop counter: 2/5
# Epoch [11/20], Step [100/860], Loss: 0.0926
# Epoch [11/20], Step [200/860], Loss: 0.0528
# Epoch [11/20], Step [300/860], Loss: 0.2232
# Epoch [11/20], Step [400/860], Loss: 0.1765
# Epoch [11/20], Step [500/860], Loss: 0.2496
# Epoch [11/20], Step [600/860], Loss: 0.1244
# Epoch [11/20], Step [700/860], Loss: 0.1560
# Epoch [11/20], Step [800/860], Loss: 0.1340
# Epoch [11/20], Train Loss: 0.1423, Train Acc: 95.20%, Val Loss: 0.2526, Val Acc: 91.16%
# No improvement. Early stop counter: 3/5
# Epoch [12/20], Step [100/860], Loss: 0.1556
# Epoch [12/20], Step [200/860], Loss: 0.0389
# Epoch [12/20], Step [300/860], Loss: 0.1627
# Epoch [12/20], Step [400/860], Loss: 0.1393
# Epoch [12/20], Step [500/860], Loss: 0.2443
# Epoch [12/20], Step [600/860], Loss: 0.0191
# Epoch [12/20], Step [700/860], Loss: 0.1561
# Epoch [12/20], Step [800/860], Loss: 0.1615
# Epoch [12/20], Train Loss: 0.1309, Train Acc: 96.02%, Val Loss: 0.2299, Val Acc: 92.26%
# Best model saved at epoch 12.
# Epoch [13/20], Step [100/860], Loss: 0.2226
# Epoch [13/20], Step [200/860], Loss: 0.0607
# Epoch [13/20], Step [300/860], Loss: 0.0867
# Epoch [13/20], Step [400/860], Loss: 0.1796
# Epoch [13/20], Step [500/860], Loss: 0.0876
# Epoch [13/20], Step [600/860], Loss: 0.0587
# Epoch [13/20], Step [700/860], Loss: 0.1469
# Epoch [13/20], Step [800/860], Loss: 0.1006
# Epoch [13/20], Train Loss: 0.1172, Train Acc: 96.67%, Val Loss: 0.2482, Val Acc: 91.92%
# No improvement. Early stop counter: 1/5
# Epoch [14/20], Step [100/860], Loss: 0.0728
# Epoch [14/20], Step [200/860], Loss: 0.1503
# Epoch [14/20], Step [300/860], Loss: 0.1844
# Epoch [14/20], Step [400/860], Loss: 0.1043
# Epoch [14/20], Step [500/860], Loss: 0.0899
# Epoch [14/20], Step [600/860], Loss: 0.0375
# Epoch [14/20], Step [700/860], Loss: 0.1765
# Epoch [14/20], Step [800/860], Loss: 0.0873
# Epoch [14/20], Train Loss: 0.1084, Train Acc: 96.15%, Val Loss: 0.2820, Val Acc: 91.52%
# No improvement. Early stop counter: 2/5
# Epoch [15/20], Step [100/860], Loss: 0.0546
# Epoch [15/20], Step [200/860], Loss: 0.0679
# Epoch [15/20], Step [300/860], Loss: 0.0545
# Epoch [15/20], Step [400/860], Loss: 0.0726
# Epoch [15/20], Step [500/860], Loss: 0.1078
# Epoch [15/20], Step [600/860], Loss: 0.0608
# Epoch [15/20], Step [700/860], Loss: 0.1535
# Epoch [15/20], Step [800/860], Loss: 0.1318
# Epoch [15/20], Train Loss: 0.1010, Train Acc: 96.51%, Val Loss: 0.2600, Val Acc: 91.76%
# No improvement. Early stop counter: 3/5
# Epoch [16/20], Step [100/860], Loss: 0.0320
# Epoch [16/20], Step [200/860], Loss: 0.0514
# Epoch [16/20], Step [300/860], Loss: 0.0152
# Epoch [16/20], Step [400/860], Loss: 0.1194
# Epoch [16/20], Step [500/860], Loss: 0.0344
# Epoch [16/20], Step [600/860], Loss: 0.2343
# Epoch [16/20], Step [700/860], Loss: 0.0877
# Epoch [16/20], Step [800/860], Loss: 0.1141
# Epoch [16/20], Train Loss: 0.0905, Train Acc: 97.31%, Val Loss: 0.2522, Val Acc: 92.32%
# No improvement. Early stop counter: 4/5
# Epoch [17/20], Step [100/860], Loss: 0.1179
# Epoch [17/20], Step [200/860], Loss: 0.0403
# Epoch [17/20], Step [300/860], Loss: 0.0471
# Epoch [17/20], Step [400/860], Loss: 0.0997
# Epoch [17/20], Step [500/860], Loss: 0.1499
# Epoch [17/20], Step [600/860], Loss: 0.1085
# Epoch [17/20], Step [700/860], Loss: 0.0570
# Epoch [17/20], Step [800/860], Loss: 0.0472
# Epoch [17/20], Train Loss: 0.0864, Train Acc: 97.51%, Val Loss: 0.2705, Val Acc: 91.70%
# No improvement. Early stop counter: 5/5
# Early stopping at epoch 17. Best epoch was 12 with best_metric=0.2299
# Loading best model weights from epoch 12

# %%
# 在测试集进行评估
# 确保导入 trainer 有 test/evaluate 方法，或直接用 model 预测
# 先将模型设置为评估模式
model.eval()
test_loss = 0.0
correct = 0
total = 0

with torch.no_grad():
    for data, targets in test_loader:
        data, targets = data.to(device), targets.to(device)
        outputs = model(data)
        loss = criterion(outputs, targets)
        test_loss += loss.item() * data.size(0)
        _, predicted = torch.max(outputs, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()

test_loss = test_loss / total
accuracy = 100 * correct / total

print(f"Test Loss: {test_loss:.3f}")
print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
# Test Loss: 0.249
# Test Accuracy: 91.33%
